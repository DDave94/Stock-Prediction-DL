# %% [markdown]
# # Tesla Stock Signal Prediction
#
# Using historical stock data to predict a "buy or sell" signal for a trading day. This notebook includes the following sections:
# - ##### Step 1: Feature Engineering
# - ##### Step 2: Data Preparation
# - ##### Step 3: Building LSTM Model to predict stock signals
# - ##### Step 4: Performing Hyperparameter Tuning
#
# Modelling and evaluation was performed without Social Media Sentiments from Twitter, this notebook will be utilized to discuss the differences of results when social media sentiment is not included in model training

# %%
# !pip install -q -U keras-tuner
# Out:
#      |████████████████████████████████| 71kB 3.3MB/s
#   Building wheel for keras-tuner (setup.py) ... done
#   Building wheel for terminaltables (setup.py) ... done

# %%
# Loading required libraries
import pandas as pd
import numpy as np

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow import keras 
from keras.models import Sequential
from keras.losses import BinaryCrossentropy
from keras.layers import Dense, LSTM, Dropout
from keras.optimizers import Adam
import matplotlib.pyplot  as plt
import kerastuner as kt

pd.set_option("display.max_colwidth" , 100, "display.max_columns", 15)
np.random.seed(54)
tf.random.set_seed(54)

# %%
# Loading Raw Tesla Stock data containing daily metrics
tsla_df = pd.read_csv("https://raw.githubusercontent.com/DDave94/Stock-Prediction-DL/main/datasets/raw/Tesla/TSLA.csv")

# Loading Twitter Sentiment data containing daily twitter sentiment scores based on daily aggregate tweet analysis
twitter_df = pd.read_csv("https://raw.githubusercontent.com/DDave94/Stock-Prediction-DL/main/datasets/tsla-tweet-sentiments-lstm.csv")

# %% [markdown]
# ### Feature Engineering
# - Generating other prediction metrics such as:
#     -  **Moving Average** : A moving average indicates the trend of the closing price movement and reduces the amount of "noise" on the price chart. We calculate different types of moving averages below.
#     - **Momentum** : The rate of acceleration at which the stock price is changing based on historical closing prices
#
# - Adding Twitter sentiment feature column, the social media sentiment scores for each day of trading. However this feature will NOT be used for model training and evaluation.
#     - This data was only merged to create the same frame of reference for instaces as the other model which included twitter sentiments in analysis. This allows us to compare and contrast the existence of social media sentiment more effectively
#
# - Generating target column "signal" using special moving averages

# %%
# Calculation of historical moving averages of closing price (10 and 30 days of trading)
def MA(df, period):
    MA = pd.Series(df['Close'].rolling(period, min_periods=period).mean(), name='MA_' + str(period))
    return MA

tsla_df['MA10'] = MA(tsla_df, 10)
tsla_df['MA30'] = MA(tsla_df, 30)

#calculation of exponential moving average of closing price (10 and 30 days of trading)
def EMA(df, period):
    EMA = pd.Series(df['Close'].ewm(span=period, min_periods=period).mean(), name='EMA_' + str(period))
    return EMA

tsla_df['EMA10'] = EMA(tsla_df, 10)
tsla_df['EMA30'] = EMA(tsla_df, 30)


#Calculation of closing price momentum (10 and 30 days of trading)
def MOM(df, period):   
    MOM = pd.Series(df.diff(period), name='Momentum_' + str(period))   
    return MOM

tsla_df['MOM10'] = MOM(tsla_df['Close'], 10)
tsla_df['MOM30'] = MOM(tsla_df['Close'], 30)

# %%
# Merging the twitter sentiment scores for each day of stock trading
# This step is only performed when utilizing sentiment for stock signal prediction

tsla_df['Date'] = tsla_df['Date'].astype(str)
twitter_df['Date'] = twitter_df['Date'].astype(str)

merged_data = pd.merge(tsla_df,twitter_df, how='inner', on='Date')

#Dropping social media sentiment data
merged_data = merged_data.drop(columns=['TwitterSentiment'])

merged_data.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2017-01-03  42.972000  44.066002  42.192001  43.397999  43.397999
# 1  2017-01-04  42.950001  45.599998  42.862000  45.397999  45.397999
# 2  2017-01-05  45.284000  45.495998  44.389999  45.349998  45.349998
# 3  2017-01-06  45.386002  46.062000  45.090000  45.801998  45.801998
# 4  2017-01-09  45.793999  46.383999  45.599998  46.256001  46.256001
#
#      Volume       MA10       MA30      EMA10      EMA30     MOM10     MOM30
# 0  29616500  42.512800  39.694600  42.387158  40.585125  2.899998  5.666001
# 1  56067500  42.998000  39.974400  42.934584  40.895634  4.851998  8.393997
# 2  29558500  43.357199  40.255933  43.373750  41.183013  3.591999  8.445999
# 3  27639500  43.783399  40.508200  43.815250  41.481012  4.261997  7.567997
# 4  19897500  44.239999  40.762467  44.259023  41.789077  4.566002  7.628003

# %%
# Creating two columns SMA and LMA to label our dataset
# SMA (Short Moving Average)- The average of the closing price from the next five days in the future
# LMA (Long Moving Average)- The average of the closing price from the last ten days and the next five days in the future

full_data = merged_data
full_data['SMA'] = ""
full_data['LMA'] = ""

for ind in range(0, (full_data.shape[0]-5)):
    sma_frame = full_data['Close'].iloc[ind+1:ind+6]
    full_data['SMA'].iloc[ind] = sma_frame.mean()
  
    lma_frame_one = full_data['Close'].iloc[ind-10:ind]
    lma_frame_two = full_data['Close'].iloc[ind+1:ind+6]

    if (lma_frame_one.sum() == 0):
        full_data['LMA'].iloc[ind] = np.NaN
    else: 
        full_data['LMA'].iloc[ind] = (lma_frame_one.sum() + lma_frame_two.sum())/15

full_data['SMA'] = full_data['SMA'].replace('', np.NaN)
full_data['LMA'] = full_data['LMA'].replace('', np.NaN)

#Dropping any empty fields of data
full_data = full_data.dropna(axis=0)
print(full_data.head())
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#           Date       Open       High        Low      Close  Adj Close  \
# 10  2017-01-18  47.330002  47.942001  47.116001  47.672001  47.672001
# 11  2017-01-19  49.450001  49.736000  48.150002  48.751999  48.751999
# 12  2017-01-20  49.091999  49.200001  48.602001  48.945999  48.945999
# 13  2017-01-23  49.169998  50.178001  49.099998  49.784000  49.784000
# 14  2017-01-24  50.000000  50.959999  49.930000  50.922001  50.922001
#
#       Volume       MA10       MA30      EMA10      EMA30     MOM10      MOM30  \
# 10  18845000  46.298199  42.534400  46.122106  43.432292  4.274002  11.378002
# 11  38661500  46.633599  42.914133  46.600269  43.775499  3.354000  11.391998
# 12  21021500  46.993199  43.306666  47.026765  44.109080  3.596001  11.776001
# 13  31314500  47.391400  43.678466  47.528081  44.475204  3.982002  11.153999
# 14  24827500  47.858000  44.093933  48.145157  44.891127  4.666000  12.464001
#
#         SMA        LMA
# 10  49.8596  47.200399
# 11  50.2096  47.602000
# 12  50.5384  47.935200
# 13  50.6068  48.197733
# 14  50.4996  48.427467

# %%
#Creating target class - Signal
# The signal on a given trading day represents either 1-Buy or 0-Sell 
# The signal is calculated by comparing the future SMA and intermediate LMA
labelled_data = full_data
labelled_data['signal'] = np.where(labelled_data['SMA'] > labelled_data['LMA'], 1.0, 0.0)

#Dropping the SMA and LMA columns to avoid data leakage
labelled_data  = labelled_data.drop(columns = ['SMA', 'LMA'])
print(labelled_data.head())
# Out:
#           Date       Open       High        Low      Close  Adj Close  \
#
0

# %%
# Creating X_test and y_test
# As an example, this function looks back at five days of trading:
# X - Consists of all features excluding signal from last 5 days 
# y - Consists of signal from one day ahead

X_test = []
y_test = []

# Gathering the last five days of training data as this 
# will be used to predict the first few labels in y_test
last_5_days = full_training_data.tail()
test_data_df = last_5_days.append([full_test_data], ignore_index=True)

for i in range(time_step, test_data_df.shape[0]):
    X_test.append(test_data_df.iloc[i-time_step:i,:label_col])
    y_test.append(test_data_df.iloc[i, label_col])

X_test, y_test = np.array(X_test), np.array(y_test)
print('\nShapes of X_test and Y_test:\n')
print(X_test.shape)
print(y_test.shape)

print('\nFirst Element in X_test and Y_test:\n')
print(X_test[0])
print(y_test[0])
# Out:
# Shapes of X_test and Y_test:
#
# (294, 5, 12)
# (294,)
#
# First Element in X_test and Y_test:
#
# [[0.02421445 0.0222971  0.0252607  0.02394396 0.02394396 0.07227146
#   0.01789002 0.01272975 0.01765    0.00949942 0.31572072 0.30861858]
#  [0.02411646 0.02293572 0.02617772 0.02450828 0.02450828 0.07654875
#   0.01844328 0.01323949 0.01843226 0.00997347 0.3184102  0.31203773]
#  [0.02573181 0.02375073 0.02724212 0.02518181 0.02518181 0.04395758
#   0.01940666 0.01366208 0.01920711 0.01047109 0.32809855 0.30834792]
#  [0.0251628  0.0231486  0.02558166 0.02365877 0.02365877 0.06064634
#   0.02025619 0.01404696 0.01953622 0.01081415 0.32540908 0.30675157]
#  [0.0244136  0.02214505 0.02397031 0.02261205 0.02261205 0.04822977
#   0.02078148 0.01433021 0.01959598 0.01105093 0.31774963 0.30244864]]
# 1.0

# %% [markdown]
# ### Intial Modeling and Evaluation
# - Building, Compiling, and Training deep learning model
# - Evaluating model by comparing predicted signals against actual signals in testing data defined by X_test and y_test

# %%
# Model definition
def build_model():

    model = Sequential()

    model.add(LSTM(units = 30, activation = 'relu',input_shape = (X_train.shape[1], X_train.shape[2])))
    model.add(Dropout(0.2))
   
    model.add(Dense(units = 10, activation = 'relu'))
           
    model.add(Dense(units = 1, activation = 'sigmoid'))
   
    print(model.summary())

    return model

# Model Compile
def compile_model(model):

    met = [keras.metrics.BinaryAccuracy(name='accuracy'),keras.metrics.Precision(name='precision'),
                keras.metrics.Recall(name='recall'), keras.metrics.AUC(name='auc')]
    
    model.compile(optimizer='adam', loss = BinaryCrossentropy(), metrics = met)

    return model

# Model Training
def train_model(model, X_train, Y_train):
    
    batch_size = 32
    epochs = 80  
       
    history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose = 1)

    return model, history

# Model Evaluation and Results Evaluation
def eval_model(m, test_X, test_y):

    y_pred = m.predict(test_X)
    y_pred = y_pred.flatten()
    
    print('CONFUSION MATRIX: \n')
    unique_label = np.unique([test_y, y_pred.round()])
    cmtx = pd.DataFrame(
    confusion_matrix(test_y, y_pred.round(), labels=unique_label), 
    index=['  true:{:}'.format(x) for x in unique_label], 
    columns=['pred:{:}'.format(x) for x in unique_label])
    print(cmtx)


    print('\nCLASSFICATION REPORT: \n')
    print(classification_report(test_y, y_pred.round()))

    # Visualising the results
    print('\nMODEL PREDICTIONS VS ACTUAL: \n')
    plt.figure(figsize=(14,5))
    plt.plot(test_y, color = 'red', label = 'Actual Buy/Sell Signal ')
    plt.plot(y_pred, color = 'blue', label = 'Predicted Buy/Sell Signal')
    plt.title('TSLA LSTM Stock Buy/Sell Prediction - Without Sentiment')
    plt.xlabel('Time')
    plt.ylabel('TSLA Stock Signal')
    plt.legend(loc='best')
    plt.show()
   
    return None

# %%
# Class Imbalance
(unique,counts) = np.unique(y_train, return_counts=True)
frequencies = np.asarray((unique, counts)).T
print('Training Instances with Class 0:  ' + str(frequencies[0][1]))
print('Training Instances with Class 1:  ' + str(frequencies[1][1]))
total = int(frequencies[0][1]) + int(frequencies[1][1])
print('Total Training instances:  '+str(total))
# Out:
# Training Instances with Class 0:  335.0
# Training Instances with Class 1:  344.0
# Total Training instances:  679

# %%
# Executing model building, compiling and training 
# During model training, we print the 
model = build_model()
model = compile_model(model)
model, history = train_model(model, X_train, y_train)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 30)                5160
# _________________________________________________________________
# dropout (Dropout)            (None, 30)                0
# _________________________________________________________________
# dense (Dense)                (None, 10)                310
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 5,481
# Trainable params: 5,481
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/80
# 22/22 [==============================] - 4s 14ms/step - loss: 0.6929 - accuracy: 0.5247 - precision: 0.5155 - recall: 0.8355 - auc: 0.5225
# Epoch 2/80
# 22/22 [==============================] - 0s 15ms/step - loss: 0.6915 - accuracy: 0.5077 - precision: 0.5011 - recall: 0.8461 - auc: 0.5806
# Epoch 3/80
# 22/22 [==============================] - 0s 15ms/step - loss: 0.6895 - accuracy: 0.5487 - precision: 0.5443 - recall: 0.9581 - auc: 0.6050
# Epoch 4/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.6903 - accuracy: 0.5437 - precision: 0.5343 - recall: 0.8408 - auc: 0.6125
# Epoch 5/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.6905 - accuracy: 0.5319 - precision: 0.5107 - recall: 0.7590 - auc: 0.6233
# Epoch 6/80
# 22/22 [==============================] - 0s 15ms/step - loss: 0.6885 - accuracy: 0.5549 - precision: 0.5441 - recall: 0.8152 - auc: 0.6175
# Epoch 7/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.6861 - accuracy: 0.5586 - precision: 0.5623 - recall: 0.6849 - auc: 0.6267
# Epoch 8/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.6804 - accuracy: 0.5899 - precision: 0.5647 - recall: 0.8399 - auc: 0.6733
# Epoch 9/80
# 22/22 [==============================] - 0s 15ms/step - loss: 0.6774 - accuracy: 0.6209 - precision: 0.6554 - recall: 0.5621 - auc: 0.6701
# Epoch 10/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.6710 - accuracy: 0.6248 - precision: 0.6049 - recall: 0.7155 - auc: 0.6798
# Epoch 11/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.6637 - accuracy: 0.5887 - precision: 0.5577 - recall: 0.8260 - auc: 0.6834
# Epoch 12/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.6510 - accuracy: 0.6420 - precision: 0.6874 - recall: 0.4871 - auc: 0.6805
# Epoch 13/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.6152 - accuracy: 0.6706 - precision: 0.6665 - recall: 0.7291 - auc: 0.7398
# Epoch 14/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.6009 - accuracy: 0.6778 - precision: 0.6803 - recall: 0.6877 - auc: 0.7482
# Epoch 15/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.5884 - accuracy: 0.6945 - precision: 0.7385 - recall: 0.6191 - auc: 0.7706
# Epoch 16/80
# 22/22 [==============================] - 0s 15ms/step - loss: 0.5506 - accuracy: 0.7275 - precision: 0.7502 - recall: 0.7118 - auc: 0.8080
# Epoch 17/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.5732 - accuracy: 0.6926 - precision: 0.7173 - recall: 0.6283 - auc: 0.7755
# Epoch 18/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.6098 - accuracy: 0.6537 - precision: 0.6428 - recall: 0.5670 - auc: 0.7433
# Epoch 19/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.5257 - accuracy: 0.7619 - precision: 0.7610 - recall: 0.7690 - auc: 0.8447
# Epoch 20/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.5138 - accuracy: 0.7504 - precision: 0.8120 - recall: 0.6846 - auc: 0.8468
# Epoch 21/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.4629 - accuracy: 0.8101 - precision: 0.7885 - recall: 0.8401 - auc: 0.8816
# Epoch 22/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.4409 - accuracy: 0.8157 - precision: 0.8187 - recall: 0.8101 - auc: 0.8843
# Epoch 23/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.4252 - accuracy: 0.7881 - precision: 0.7971 - recall: 0.7861 - auc: 0.8890
# Epoch 24/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.4035 - accuracy: 0.8080 - precision: 0.8112 - recall: 0.8304 - auc: 0.9013
# Epoch 25/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.4317 - accuracy: 0.7810 - precision: 0.7900 - recall: 0.7869 - auc: 0.8838
# Epoch 26/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.4087 - accuracy: 0.8151 - precision: 0.8122 - recall: 0.8210 - auc: 0.8959
# Epoch 27/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.4467 - accuracy: 0.7848 - precision: 0.8377 - recall: 0.7595 - auc: 0.8812
# Epoch 28/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.3949 - accuracy: 0.8338 - precision: 0.8336 - recall: 0.8348 - auc: 0.9055
# Epoch 29/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.4193 - accuracy: 0.7974 - precision: 0.8344 - recall: 0.7631 - auc: 0.8929
# Epoch 30/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.4379 - accuracy: 0.8134 - precision: 0.8486 - recall: 0.7760 - auc: 0.8785
# Epoch 31/80
# 22/22 [==============================] - 0s 15ms/step - loss: 0.4160 - accuracy: 0.7980 - precision: 0.7935 - recall: 0.8028 - auc: 0.8940
# Epoch 32/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.4014 - accuracy: 0.8050 - precision: 0.8273 - recall: 0.7752 - auc: 0.9042
# Epoch 33/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.3964 - accuracy: 0.8193 - precision: 0.8017 - recall: 0.8417 - auc: 0.9056
# Epoch 34/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.3787 - accuracy: 0.8309 - precision: 0.8256 - recall: 0.8387 - auc: 0.9101
# Epoch 35/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.3815 - accuracy: 0.8248 - precision: 0.8064 - recall: 0.8463 - auc: 0.9128
# Epoch 36/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.3807 - accuracy: 0.8229 - precision: 0.8656 - recall: 0.7809 - auc: 0.9165
# Epoch 37/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.4213 - accuracy: 0.8107 - precision: 0.8145 - recall: 0.8402 - auc: 0.8906
# Epoch 38/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.4036 - accuracy: 0.8047 - precision: 0.8418 - recall: 0.7734 - auc: 0.9031
# Epoch 39/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.3741 - accuracy: 0.8279 - precision: 0.8181 - recall: 0.8408 - auc: 0.9176
# Epoch 40/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.3494 - accuracy: 0.8516 - precision: 0.8698 - recall: 0.8458 - auc: 0.9267
# Epoch 41/80
# 22/22 [==============================] - 0s 15ms/step - loss: 0.3736 - accuracy: 0.8164 - precision: 0.7884 - recall: 0.8518 - auc: 0.9199
# Epoch 42/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.3711 - accuracy: 0.8224 - precision: 0.8183 - recall: 0.8251 - auc: 0.9130
# Epoch 43/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.3675 - accuracy: 0.8345 - precision: 0.8464 - recall: 0.8252 - auc: 0.9182
# Epoch 44/80
# 22/22 [==============================] - 0s 15ms/step - loss: 0.3577 - accuracy: 0.8437 - precision: 0.8414 - recall: 0.8574 - auc: 0.9207
# Epoch 45/80
# 22/22 [==============================] - 0s 15ms/step - loss: 0.3332 - accuracy: 0.8540 - precision: 0.8532 - recall: 0.8588 - auc: 0.9314
# Epoch 46/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.
80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.3701 - accuracy: 0.8301 - precision: 0.8438 - recall: 0.8202 - auc: 0.9184
# Epoch 77/80
# 22/22 [==============================] - 0s 14ms/step - loss: 0.3773 - accuracy: 0.8417 - precision: 0.8198 - recall: 0.8980 - auc: 0.9160
# Epoch 78/80
# 22/22 [==============================] - 0s 15ms/step - loss: 0.3608 - accuracy: 0.8413 - precision: 0.8077 - recall: 0.8909 - auc: 0.9204
# Epoch 79/80
# 22/22 [==============================] - 0s 15ms/step - loss: 0.4094 - accuracy: 0.8320 - precision: 0.8502 - recall: 0.7874 - auc: 0.9019
# Epoch 80/80
# 22/22 [==============================] - 0s 15ms/step - loss: 0.3177 - accuracy: 0.8638 - precision: 0.8493 - recall: 0.8856 - auc: 0.9405

# %%
# Plotting Training loss vs Epochs 
def plot_curves(history): 
    
    print('\nMODEL TRAINING RESULTS\n')
    plt.figure(figsize=(10,10))
    plt.plot(history.history['loss'], color = 'blue')
    plt.plot(history.history['accuracy'], color = 'red')
    plt.title('Model Training Loss & Accuracy vs Epochs')
    plt.xlabel('Training Epochs')
    plt.legend(['Train Loss', 'Train Accuracy'], loc='best')
    plt.show()
        
plot_curves(history)
# Out:
# MODEL TRAINING RESULTS

# %%
# Testing Initial Model 
# Printing Confusion Matrix, Classification Report, and Visualizing Predicted Signal
tf.keras.utils.plot_model(model, to_file='TSLA-LSTM-without-Sentiment-Normal.png', show_shapes=True)
eval_model(model, X_test, y_test)
# Out:
# CONFUSION MATRIX:
#
#             pred:0.0  pred:1.0
#   true:0.0        24        39
#   true:1.0         3       228
#
# CLASSFICATION REPORT:
#
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.38      0.53        63
#          1.0       0.85      0.99      0.92       231
#
#     accuracy                           0.86       294
#    macro avg       0.87      0.68      0.72       294
# weighted avg       0.86      0.86      0.83       294
#
#
# MODEL PREDICTIONS VS ACTUAL:

# %% [markdown]
# ### Hyperparameter Tuning
# - Creating Hyper parameter model and using the RandomSearch tuner class for performing tuning.
# - Tuner obtains the best values for hyperparameters such as input llayer units, input lyaer dropout, hidden layer cells, and learning rate
# - Using the best values, we create another model to find the optimal number
# of epochs which minimizes training loss
# - Lastly, create a final model which uses the optimal values for hyperparameters and epochs to build the best model and performing evaluation

# %%
def model_builder(hp):

    #Defining Model 
    hyper_model = Sequential()

    hyper_model.add(LSTM(units = hp.Int('input_layer', 10, 90, step=10), activation = 'relu', input_shape = (X_train.shape[1], X_train.shape[2])))
    hyper_model.add(Dropout(hp.Choice('Drop1', values = [0.1,0.2,0.3])))
        
    hyper_model.add(Dense(units = hp.Choice('hidden_1', values = [10,20,30,60,80,100]), activation = 'relu'))
        
    hyper_model.add(Dense(units = 1, activation = 'sigmoid'))
        
    hyper_model.compile(optimizer = Adam(learning_rate=hp.Choice('learning_rate', values = [1e-2, 1e-3, 1e-4])),
                        loss = BinaryCrossentropy(), metrics=['accuracy'])
        
    return hyper_model

# %%
# Defining Random Search Tuner and performing hyperparameter tuning
obj = kt.Objective("loss", direction="min")
tuner = kt.tuners.randomsearch.RandomSearch(model_builder, objective=obj, max_trials=25, seed=42, overwrite = True)

tuner.search(X_train, y_train, epochs=80)

# Get the optimal hyperparameter values for model layers
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
The hyperparameter search is complete. 

The optimal number of units in the input layer is {best_hps.get('input_layer')}. 
The optimal amount of dropout in the input layer is {best_hps.get('Drop1')}. 
The optimal number of units in the first hidden layer is {best_hps.get('hidden_1')}. 
The optimal learning rate is {best_hps.get('learning_rate')}.
""")
# Out:
# Trial 25 Complete [00h 00m 24s]
# loss: 0.6481172442436218
#
# Best loss So Far: 0.2881552278995514
# Total elapsed time: 00h 10m 02s
# INFO:tensorflow:Oracle triggered exit
#
# The hyperparameter search is complete.
#
# The optimal number of units in the input layer is 80.
# The optimal amount of dropout in the input layer is 0.2.
# The optimal number of units in the first hidden layer is 80.
# The optimal learning rate is 0.01.

# %% [markdown]
# #### Evaluating Tuned Model
# - In Step One, we create the model using the best hyperparameter values identified during tuning. Then we find the epoch in which we obtain our objective.
#
# - In Step Two, we recreate the model using the optimal hyperparameter values and the ideal number of training epochs. Then we train and evaluate this model to compare results against the first non-tuned model with random parameters

# %%
#Step One
model_Two = tuner.hypermodel.build(best_hps)
history = model_Two.fit(X_train, y_train, epochs=80)

acc_per_epoch = history.history['accuracy']
best_epoch = acc_per_epoch.index(max(acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/80
# 22/22 [==============================] - 2s 12ms/step - loss: 0.6961 - accuracy: 0.4784
# Epoch 2/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.6879 - accuracy: 0.5237
# Epoch 3/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.6844 - accuracy: 0.5752
# Epoch 4/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.6583 - accuracy: 0.6677
# Epoch 5/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.6447 - accuracy: 0.6175
# Epoch 6/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.5593 - accuracy: 0.7190
# Epoch 7/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.8091 - accuracy: 0.5575
# Epoch 8/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.6791 - accuracy: 0.6139
# Epoch 9/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.6153 - accuracy: 0.7785
# Epoch 10/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4935 - accuracy: 0.7865
# Epoch 11/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4400 - accuracy: 0.8072
# Epoch 12/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.5388 - accuracy: 0.7475
# Epoch 13/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4672 - accuracy: 0.7663
# Epoch 14/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4382 - accuracy: 0.7834
# Epoch 15/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4319 - accuracy: 0.7905
# Epoch 16/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4082 - accuracy: 0.8072
# Epoch 17/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4974 - accuracy: 0.7510
# Epoch 18/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.5931 - accuracy: 0.6722
# Epoch 19/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.5150 - accuracy: 0.7900
# Epoch 20/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.6051 - accuracy: 0.6786
# Epoch 21/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4479 - accuracy: 0.8001
# Epoch 22/80
# 22/22 [==============================] - 0s 13ms/step - loss: 0.4231 - accuracy: 0.8077
# Epoch 23/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3618 - accuracy: 0.8223
# Epoch 24/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3538 - accuracy: 0.8446
# Epoch 25/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3975 - accuracy: 0.8139
# Epoch 26/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3720 - accuracy: 0.8157
# Epoch 27/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4608 - accuracy: 0.7850
# Epoch 28/80
# 22/22 [==============================] - 0s 13ms/step - loss: 0.3628 - accuracy: 0.8314
# Epoch 29/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4146 - accuracy: 0.8014
# Epoch 30/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4107 - accuracy: 0.8214
# Epoch 31/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3658 - accuracy: 0.8463
# Epoch 32/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3536 - accuracy: 0.8295
# Epoch 33/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4299 - accuracy: 0.8040
# Epoch 34/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4138 - accuracy: 0.8151
# Epoch 35/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3596 - accuracy: 0.8426
# Epoch 36/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3183 - accuracy: 0.8574
# Epoch 37/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3706 - accuracy: 0.8261
# Epoch 38/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3685 - accuracy: 0.8172
# Epoch 39/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3471 - accuracy: 0.8507
# Epoch 40/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3414 - accuracy: 0.8536
# Epoch 41/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3049 - accuracy: 0.8565
# Epoch 42/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4239 - accuracy: 0.7774
# Epoch 43/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4975 - accuracy: 0.7906
# Epoch 44/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3592 - accuracy: 0.8432
# Epoch 45/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.2938 - accuracy: 0.8733
# Epoch 46/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3353 - accuracy: 0.8433
# Epoch 47/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3739 - accuracy: 0.8555
# Epoch 48/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3218 - accuracy: 0.8330
# Epoch 49/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3027 - accuracy: 0.8728
# Epoch 50/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3894 - accuracy: 0.8191
# Epoch 51/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3409 - accuracy: 0.8258
# Epoch 52/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3707 - accuracy: 0.8493
# Epoch 53/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.2986 - accuracy: 0.8645
# Epoch 54/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4521 - accuracy: 0.8139
# Epoch 55/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3811 - accuracy: 0.8004
# Epoch 56/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3459 - accuracy: 0.8394
# Epoch 57/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3434 - accuracy: 0.8405
# Epoch 58/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.2899 - accuracy: 0.8631
# Epoch 59/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.2974 - accuracy: 0.8494
# Epoch 60/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.2990 - accuracy: 0.8629
# Epoch 61/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.2705 - accuracy: 0.8760
# Epoch 62/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3154 - accuracy: 0.8403
# Epoch 63/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.2919 - accuracy: 0.8484
# Epoch 64/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.2852 - accuracy: 0.8869
# Epoch 65/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3170 - accuracy: 0.8393
# Epoch 66/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3454 - accuracy: 0.8365
# Epoch 67/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3785 - accuracy: 0.8291
# Epoch 68/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4162 - accuracy: 0.7779
# Epoch 69/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3656 - accuracy: 0.8264
# Epoch 70/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3391 - accuracy: 0.8648
# Epoch 71/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3104 - accuracy: 0.8714
# Epoch 72/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3151 - accuracy: 0.8462
# Epoch 73/80
# 22/22 [==============================] - 0s 13ms/step - loss: 0.3790 - accuracy: 0.8441
# Epoch 74/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.2904 - accuracy: 0.8526
# Epoch 75/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3210 - accuracy: 0.8422
# Epoch 76/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3313 - accuracy: 0.8349
# Epoch 77/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3880 - accuracy: 0.8171
# Epoch 78/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3082 - accuracy: 0.8573
# Epoch 79/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4078 - accuracy: 0.8221
# Epoch 80/80
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4450 - accuracy: 0.8055
# Best epoch: 70

# %%
#Step Two
model_three = tuner.hypermodel.build(best_hps)

# Retrain the final model using the best number of epochs
tuned_history = model_three.fit(X_train, y_train, epochs=best_epoch)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/70
# 22/22 [==============================] - 2s 12ms/step - loss: 0.6985 - accuracy: 0.4776
# Epoch 2/70
# 22/22 [==============================] - 0s 11ms/step - loss: 0.6894 - accuracy: 0.5104
# Epoch 3/70
# 22/22 [==============================] - 0s 11ms/step - loss: 0.6832 - accuracy: 0.5560
# Epoch 4/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.6546 - accuracy: 0.5820
# Epoch 5/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.6861 - accuracy: 0.5507
# Epoch 6/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.6369 - accuracy: 0.6506
# Epoch 7/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.5871 - accuracy: 0.6783
# Epoch 8/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.8683 - accuracy: 0.5907
# Epoch 9/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.6125 - accuracy: 0.7674
# Epoch 10/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.5293 - accuracy: 0.7424
# Epoch 11/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.5307 - accuracy: 0.7433
# Epoch 12/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4824 - accuracy: 0.7766
# Epoch 13/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4364 - accuracy: 0.8056
# Epoch 14/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4586 - accuracy: 0.7903
# Epoch 15/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4581 - accuracy: 0.7593
# Epoch 16/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4100 - accuracy: 0.8020
# Epoch 17/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4830 - accuracy: 0.7677
# Epoch 18/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.6118 - accuracy: 0.6814
# Epoch 19/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4747 - accuracy: 0.7981
# Epoch 20/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.5951 - accuracy: 0.7162
# Epoch 21/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4298 - accuracy: 0.8149
# Epoch 22/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4588 - accuracy: 0.8028
# Epoch 23/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3816 - accuracy: 0.8411
# Epoch 24/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4142 - accuracy: 0.8026
# Epoch 25/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3898 - accuracy: 0.8311
# Epoch 26/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4011 - accuracy: 0.8154
# Epoch 27/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.5033 - accuracy: 0.7454
# Epoch 28/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3894 - accuracy: 0.8227
# Epoch 29/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3921 - accuracy: 0.8311
# Epoch 30/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4722 - accuracy: 0.7634
# Epoch 31/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3949 - accuracy: 0.8178
# Epoch 32/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3743 - accuracy: 0.8128
# Epoch 33/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4741 - accuracy: 0.7642
# Epoch 34/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3718 - accuracy: 0.8337
# Epoch 35/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3690 - accuracy: 0.8268
# Epoch 36/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3583 - accuracy: 0.8375
# Epoch 37/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3852 - accuracy: 0.8009
# Epoch 38/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3493 - accuracy: 0.8373
# Epoch 39/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3446 - accuracy: 0.8529
# Epoch 40/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3227 - accuracy: 0.8445
# Epoch 41/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3369 - accuracy: 0.8494
# Epoch 42/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3436 - accuracy: 0.8343
# Epoch 43/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3149 - accuracy: 0.8464
# Epoch 44/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3210 - accuracy: 0.8520
# Epoch 45/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.2981 - accuracy: 0.8701
# Epoch 46/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3362 - accuracy: 0.8413
# Epoch 47/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4749 - accuracy: 0.7843
# Epoch 48/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3811 - accuracy: 0.8201
# Epoch 49/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4029 - accuracy: 0.8265
# Epoch 50/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4290 - accuracy: 0.8061
# Epoch 51/70
# 22/22 [==============================] - 0s 11ms/step - loss: 0.3332 - accuracy: 0.8217
# Epoch 52/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3804 - accuracy: 0.8508
# Epoch 53/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3119 - accuracy: 0.8524
# Epoch 54/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3437 - accuracy: 0.8605
# Epoch 55/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3559 - accuracy: 0.8407
# Epoch 56/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3747 - accuracy: 0.8271
# Epoch 57/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3288 - accuracy: 0.8308
# Epoch 58/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.2923 - accuracy: 0.8691
# Epoch 59/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3384 - accuracy: 0.8271
# Epoch 60/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3168 - accuracy: 0.8535
# Epoch 61/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.2749 - accuracy: 0.8573
# Epoch 62/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3430 - accuracy: 0.8506
# Epoch 63/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3115 - accuracy: 0.8546
# Epoch 64/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.2842 - accuracy: 0.8733
# Epoch 65/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4310 - accuracy: 0.7788
# Epoch 66/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4189 - accuracy: 0.8059
# Epoch 67/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4376 - accuracy: 0.7897
# Epoch 68/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.4082 - accuracy: 0.8068
# Epoch 69/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3360 - accuracy: 0.8371
# Epoch 70/70
# 22/22 [==============================] - 0s 12ms/step - loss: 0.3530 - accuracy: 0.8331

# %%
plot_curves(tuned_history)
# Out:
# MODEL TRAINING RESULTS

# %%
# Tuned Model Evaluation
# Printing Confusion Matrix, Classification Report, and Visualizing the Predicted Signal
eval_result = model_three.evaluate(X_test, y_test)
print("[test loss, test accuracy]:", eval_result)
tf.keras.utils.plot_model(model_three, to_file='TSLA-LSTM-without-Sentiment-Tuned.png', show_shapes=True)
eval_model(model_three, X_test, y_test)
# Out:
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5353 - accuracy: 0.8605
# [test loss, test accuracy]: [0.5353480577468872, 0.8605442047119141]
# CONFUSION MATRIX:
#
#             pred:0.0  pred:1.0
#   true:0.0        27        36
#   true:1.0         5       226
#
# CLASSFICATION REPORT:
#
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.43      0.57        63
#          1.0       0.86      0.98      0.92       231
#
#     accuracy                           0.86       294
#    macro avg       0.85      0.70      0.74       294
# weighted avg       0.86      0.86      0.84       294
#
#
# MODEL PREDICTIONS VS ACTUAL:

# %%
#Importing required libs
import snscrape.modules.twitter as sntwitter
import pandas as pd
import datetime 
import csv

# %%
# Creating a list of dates that we will be using to pull data from 
# In the for loop below, the query uses adjacent elements to set start and end dates.
# In the example below, we are creating a list of dates from Jan 1, 2016 + 365 days

dates = []
date = datetime.datetime(2019, 1, 1)
dates.append(date)

for i in range(1,365):
    date += datetime.timedelta(days=1)
    dates.append(date)

# %%
# Variable below used to cap the number of extracted tweets for a given date
maxTweets = 10

# Creating list to append tweet data 
tweets_list2 = []


#Iterating through all the days in the list created previously
for i in range(0,len(dates)-1):
    
    #Creating query
    if ((i+1) > len(dates)):
        break
    else:
        q = 'Microsoft stock $MSFT lang:"en" since:'+str(dates[i].date())+' until:'+str(dates[i+1].date()) 

    #Using TwitterSearchScraper to scrape data and append tweets to list
    for i,tweet in enumerate(sntwitter.TwitterSearchScraper(q).get_items()):
        if i>maxTweets:
            break
        else:
            tweets_list2.append([tweet.date, tweet.content])

# %%
# Creating a dataframe from the tweets list above
tweets_df2 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Text'])

# Display first 5 entries from dataframe
print(tweets_df2.head(44))

# Export dataframe into a CSV
tweets_df2.to_csv('msft-tweets-2019.csv', sep=',', index=False, encoding = 'utf-8-sig')
# Out:
#                     Datetime  \
# 0  2019-01-01 19:40:51+00:00
# 1  2019-01-02 19:57:01+00:00
# 2  2019-01-02 13:28:54+00:00
# 3  2019-01-02 11:24:46+00:00
# 4  2019-01-02 11:24:29+00:00
# 5  2019-01-02 11:24:03+00:00
# 6  2019-01-03 17:06:27+00:00
# 7  2019-01-03 11:35:55+00:00
# 8  2019-01-03 11:35:13+00:00
# 9  2019-01-04 17:50:04+00:00
# 10 2019-01-04 15:08:38+00:00
# 11 2019-01-04 11:27:04+00:00
# 12 2019-01-05 16:33:29+00:00
# 13 2019-01-05 11:40:26+00:00
# 14 2019-01-07 18:25:40+00:00
# 15 2019-01-07 18:25:37+00:00
# 16 2019-01-07 17:16:34+00:00
# 17 2019-01-07 03:25:30+00:00
# 18 2019-01-07 02:42:54+00:00
# 19 2019-01-08 03:20:58+00:00
# 20 2019-01-09 18:08:26+00:00
# 21 2019-01-09 11:06:52+00:00
# 22 2019-01-10 20:12:27+00:00
# 23 2019-01-10 14:41:10+00:00
# 24 2019-01-10 11:19:45+00:00
# 25 2019-01-11 17:46:11+00:00
# 26 2019-01-11 17:41:12+00:00
# 27 2019-01-14 18:51:28+00:00
# 28 2019-01-14 00:46:24+00:00
# 29 2019-01-14 00:40:37+00:00
# 30 2019-01-15 21:57:38+00:00
# 31 2019-01-15 21:48:46+00:00
# 32 2019-01-15 21:37:03+00:00
# 33 2019-01-15 21:03:15+00:00
# 34 2019-01-15 20:47:09+00:00
# 35 2019-01-15 20:09:14+00:00
# 36 2019-01-15 20:06:31+00:00
# 37 2019-01-15 20:03:39+00:00
# 38 2019-01-15 19:52:56+00:00
# 39 2019-01-15 18:57:17+00:00
# 40 2019-01-15 17:23:40+00:00
# 41 2019-01-16 21:47:31+00:00
# 42 2019-01-16 20:27:52+00:00
# 43 2019-01-16 17:49:31+00:00
#
#                                                  Text
# 0   Microsoft Corporation (NASDAQ:MSFT) – Hot Stoc...
# 1   Interestingly, none of the #FANG #FAANG stocks...
# 2   Dianne Feinstein’s Husband Sold Stock in Apple...
# 3   As Microsoft Corp $MSFT Stock Declined, Shareh...
# 4   Microsoft Corp $MSFT Holder Locust Wood Capita...
# 5   As Microsoft Corp $MSFT Stock Price Declined, ...
# 6   $MSFT  Microsoft Stock Is Finally a Short\n\nh...
# 7   Ngam Advisors LP Raised Its Position in Micros...
# 8   Ngam Advisors LP Has Raised Its Microsoft Corp...
# 9   Stock Alert For MSFT - Microsoft Corporation\n...
# 10  Microsoft is probably the only tech stock I’ll...
# 11  Waverton Investment Management LTD Stake in Mi...
# 12  Stock Trends Report on Microsoft Corp $MSFT - ...
# 13  Microsoft Corp $MSFT Stock Sentiment  Worsens ...
# 14  $MSFT $SPRT Microsoft Stock Could Enter Bear M...
# 15  $MSFT Why Microsoft Is a Great Dividend Growth...
# 16  Basically $MSFT has been oe of the most stable...
# 17  $MSFT Why Microsoft Is a Great Dividend Growth...
# 18  Recommendation Buy on Technology Stock: Micros...
# 19  Why Microsoft Is a Great Dividend Growth Stock...
# 20  WJS : The Swiss central bank recently owned $3...
# 21  As Microsoft Corp $MSFT Stock Declined, Allian...
# 22  The December 2018 Snapshot 15 Summary:\nThe PB...
# 23  $MSFT #Microsoft Stock Will Rule the Future Wh...
# 24  As Microsoft Corporation Com Us$0.0000125 $MSF...
# 25  $MSFT holding multiple timeframe resistance at...
# 26  Microsoft remains a buy. It and Twilio are my ...
# 27  Top story: Microsoft $MSFT Technical Update – ...
# 28  The longest period Microsoft stock $MSFT had b...
# 29  $MSFT Microsoft \nValuation, Earnings Quality,...
# 30  Microsoft Stock, Salesforce, Palo Alto Rated T...
# 31  $MSFT Up 2.8% Today.\nMicrosoft \nValuation, E...
# 32  $CRM $PANW $MSFT Microsoft Stock, Salesforce, ...
# 33  Intel $INTC Stock Value Rose While Chemung Can...
# 34  Bank Of Nova Scotia Halifax $BNS Shareholder T...
# 35  Cornerstone Advisors Cut Stake in Microsoft $M...
# 36  Microsoft $MSFT Stock Declined While Fulton Ba...
# 37  Microsoft $MSFT Holder Golub Group Cut Its Sta...
# 38  Sgen $SGEN Holding Held by Jgp Global Gestao D...
# 39  $CRM $PANW $MSFT -- Microsoft Stock, Salesforc...
# 40  Evanson Asset Management Stake in Microsoft $M...
# 41  As Microsoft $MSFT Stock Price Declined, Capit...
# 42  Whittier Trust Co Raised Its Position in Micro...
# 43  Bio Rad Labs Cl A $BIO Stock Declined While Do...

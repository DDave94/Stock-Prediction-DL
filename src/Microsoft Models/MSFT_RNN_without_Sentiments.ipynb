# %% [markdown]
# # Microsoft Stock Signal Prediction
#
# Using historical stock data to predict a "buy or sell" signal for a trading day. This notebook includes the following sections:
# - ##### Step 1: Feature Engineering
# - ##### Step 2: Data Preparation
# - ##### Step 3: Building RNN Model to predict stock signals
# - ##### Step 4: Performing Hyperparameter Tuning
#
# Modelling and evaluation was performed without Social Media Sentiments from Twitter, this notebook will be utilized to discuss the differences of results when social media sentiment is not included in model training

# %%
# !pip install -q -U keras-tuner
# Out:
#      |████████████████████████████████| 71kB 6.6MB/s
#   Building wheel for keras-tuner (setup.py) ... done
#   Building wheel for terminaltables (setup.py) ... done

# %%
# Loading required libraries
import pandas as pd
import numpy as np

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow import keras 
from keras.models import Sequential
from keras.losses import BinaryCrossentropy
from keras.layers import Dense, SimpleRNNCell, RNN, Dropout
from keras.optimizers import Adam
import matplotlib.pyplot  as plt
import kerastuner as kt

pd.set_option("display.max_colwidth" , 100, "display.max_columns", 15)
np.random.seed(54)
tf.random.set_seed(54)

# %%
# Loading Raw Microsoft Stock data containing daily metrics
msft_df = pd.read_csv("https://raw.githubusercontent.com/DDave94/Stock-Prediction-DL/main/datasets/raw/Microsoft/MSFT.csv")

# Loading Twitter Sentiment data containing daily twitter sentiment scores based on daily aggregate tweet analysis
twitter_df = pd.read_csv("https://raw.githubusercontent.com/DDave94/Stock-Prediction-DL/main/datasets/msft-tweet-sentiments-lstm.csv")

# %% [markdown]
# ### Feature Engineering
# - Generating other prediction metrics such as:
#     -  **Moving Average** : A moving average indicates the trend of the closing price movement and reduces the amount of "noise" on the price chart. We calculate different types of moving averages below.
#     - **Momentum** : The rate of acceleration at which the stock price is changing based on historical closing prices
#
# - Adding Twitter sentiment feature column, the social media sentiment scores for each day of trading. However this feature will NOT be used for model training and evaluation.
#     - This data was only merged to create the same frame of reference for instaces as the other model which included twitter sentiments in analysis. This allows us to compare and contrast the existence of social media sentiment more effectively
#
# - Generating target column "signal" using special moving averages

# %%
# Calculation of historical moving averages of closing price (10 and 30 days of trading)
def MA(df, period):
    MA = pd.Series(df['Close'].rolling(period, min_periods=period).mean(), name='MA_' + str(period))
    return MA

msft_df['MA10'] = MA(msft_df, 10)
msft_df['MA30'] = MA(msft_df, 30)

#calculation of exponential moving average of closing price (10 and 30 days of trading)
def EMA(df, period):
    EMA = pd.Series(df['Close'].ewm(span=period, min_periods=period).mean(), name='EMA_' + str(period))
    return EMA

msft_df['EMA10'] = EMA(msft_df, 10)
msft_df['EMA30'] = EMA(msft_df, 30)


#Calculation of closing price momentum (10 and 30 days of trading)
def MOM(df, period):   
    MOM = pd.Series(df.diff(period), name='Momentum_' + str(period))   
    return MOM

msft_df['MOM10'] = MOM(msft_df['Close'], 10)
msft_df['MOM30'] = MOM(msft_df['Close'], 30)

# %%
# Merging the twitter sentiment scores for each day of stock trading
# This step is only performed when utilizing sentiment for stock signal prediction

msft_df['Date'] = msft_df['Date'].astype(str)
twitter_df['Date'] = twitter_df['Date'].astype(str)

merged_data = pd.merge(msft_df,twitter_df, how='inner', on='Date')

#Dropping social media sentiment data
merged_data = merged_data.drop(columns=['TwitterSentiment'])

merged_data.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2017-01-03  62.790001  62.840000  62.130001  62.580002  58.538418
# 1  2017-01-04  62.480000  62.750000  62.119999  62.299999  58.276497
# 2  2017-01-05  62.189999  62.660000  62.029999  62.299999  58.276497
# 3  2017-01-06  62.299999  63.150002  62.040001  62.840000  58.781628
# 4  2017-01-09  62.759998  63.080002  62.540001  62.639999  58.594547
#
#      Volume       MA10       MA30      EMA10      EMA30     MOM10     MOM30
# 0  20694100  63.138001  61.742667  62.759953  61.864946  0.280003  1.940003
# 1  21340000  63.006001  61.807667  62.676325  61.893014 -1.320000  1.950001
# 2  24876000  62.882000  61.855667  62.607902  61.919271 -1.240002  1.439998
# 3  19922900  62.812000  61.913000  62.650102  61.978673 -0.700001  1.720001
# 4  20382700  62.721000  61.987667  62.648265  62.021339 -0.910000  2.239997

# %%
# Creating two columns SMA and LMA to label our dataset
# SMA (Short Moving Average)- The average of the closing price from the next five days in the future
# LMA (Long Moving Average)- The average of the closing price from the last ten days and the next five days in the future

full_data = merged_data
full_data['SMA'] = ""
full_data['LMA'] = ""

for ind in range(0, (full_data.shape[0]-5)):
    sma_frame = full_data['Close'].iloc[ind+1:ind+6]
    full_data['SMA'].iloc[ind] = sma_frame.mean()
  
    lma_frame_one = full_data['Close'].iloc[ind-10:ind]
    lma_frame_two = full_data['Close'].iloc[ind+1:ind+6]

    if (lma_frame_one.sum() == 0):
        full_data['LMA'].iloc[ind] = np.NaN
    else: 
        full_data['LMA'].iloc[ind] = (lma_frame_one.sum() + lma_frame_two.sum())/15

full_data['SMA'] = full_data['SMA'].replace('', np.NaN)
full_data['LMA'] = full_data['LMA'].replace('', np.NaN)

#Dropping any empty fields of data
full_data = full_data.dropna(axis=0)
print(full_data.head())
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#           Date       Open       High        Low      Close  Adj Close  \
# 10  2017-01-18  62.669998  62.700001  62.119999  62.500000  58.463589
# 11  2017-01-19  62.240002  62.980000  62.200001  62.299999  58.276497
# 12  2017-01-20  62.669998  62.820000  62.369999  62.740002  58.688091
# 13  2017-01-23  62.700001  63.119999  62.570000  62.959999  58.893887
# 14  2017-01-24  63.200001  63.740002  62.939999  63.520000  59.417717
#
#       Volume    MA10       MA30      EMA10      EMA30     MOM10     MOM30  \
# 10  19670100  62.623  62.494667  62.648456  62.237743 -0.080002  3.250000
# 11  18451700  62.623  62.564000  62.585100  62.241760  0.000000  2.079998
# 12  30213500  62.667  62.657000  62.613264  62.273904  0.440003  2.790001
# 13  23097600  62.679  62.710000  62.676307  62.318169  0.119999  1.590000
# 14  24672900  62.767  62.793667  62.829705  62.395706  0.880001  2.510002
#
#           SMA        LMA
# 10  63.040000  62.767333
# 11  63.434000  62.893333
# 12  64.041999  63.095999
# 13  64.475999  63.269999
# 14  64.701999  63.353333

# %%
#Creating target class - Signal
# The signal on a given trading day represents either 1-Buy or 0-Sell 
# The signal is calculated by comparing the future SMA and intermediate LMA
labelled_data = full_data
labelled_data['signal'] = np.where(labelled_data['SMA'] > labelled_data['LMA'], 1.0, 0.0)

#Dropping the SMA and LMA columns to avoid data leakage
labelled_data  = labelled_data.drop(columns = ['SMA', 'LMA'])
print(labelled_data.head())
# Out:
#           Date       Open       High        Low      Close  Adj Close  \
# 10  2017-01-18  62.669998  62.700001  62.119999  62.500000  58.463589
# 11  2017-01-19  62.240002  62.980000  62.200001  62.299999  58.276497
# 12  2017-01-20  62.669998  62.820000  62.369999  62.740002  58.688091
# 13  2017-01-23  62.700001  63.119999  62.570000  62.959999  58.893887
# 14  2017-01-24  63.200001  63.740002  62.939999  63.520000  59.417717
#
#       Volume    MA10       MA30      EMA10      EMA30     MOM10     MOM30  \
# 10  19670100  62.623  62.494667  62.648456  62.237743 -0.080002  3.250000
# 11  18451700  62.623  62.564000  62.585100  62.241760  0.000000  2.079998
# 12  30213500  62.667  62.657000  62.613264  62.273904  0.440003  2.790001
# 13  23097600  62.679  62.710000  62.676307  62.318169  0.119999  1.590000
# 14  24672900  62.767  62.793667  62.829705  62.395706  0.880001  2.510002
#
#     signal
# 10     1.0
# 11     1.0
# 12     1.0
# 13     1.0
# 14     1.0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %% [markdown]
# ### Data Preparation
# - Scaling all features (except 'Date' and 'Signal') in labelled dataset before model training
# - Creating time series datasets for model input and evaluation

# %%
# Creating the MinMaxScaler Object
scaler = MinMaxScaler()

temp = labelled_data.drop(['Date', 'signal'], axis=1)
cols = temp.columns

#Creating scaled data
temp = scaler.fit_transform(temp)

#Generating input_df which will be used for model training and predictions
input_df = pd.concat([labelled_data['Date'],pd.DataFrame(temp, columns = cols),
                      labelled_data['signal']], 
                      axis=1, ignore_index=False)

input_df = input_df.dropna(axis=0)
print(input_df.head())
print(input_df.tail())
# Out:
#           Date      Open      High       Low     Close  Adj Close    Volume  \
# 10  2017-01-18  0.012692  0.011284  0.008170  0.007558   0.006952  0.300063
# 11  2017-01-19  0.006047  0.004173  0.003813  0.005137   0.004725  0.360262
# 12  2017-01-20  0.007544  0.005877  0.005750  0.008149   0.007495  0.208430
# 13  2017-01-23  0.007544  0.005583  0.006173  0.007913   0.007278  0.105691
# 14  2017-01-24  0.008980  0.006347  0.006718  0.006673   0.006137  0.110393
#
#         MA10      MA30     EMA10     EMA30     MOM10     MOM30  signal
# 10  0.007754  0.004672  0.008720  0.005596  0.576808  0.530694     1.0
# 11  0.008299  0.004574  0.007797  0.005629  0.573657  0.512029     1.0
# 12  0.008888  0.004605  0.007620  0.005874  0.574707  0.518395     1.0
# 13  0.009314  0.004626  0.007429  0.006087  0.570807  0.517963     1.0
# 14  0.009257  0.004600  0.007036  0.006197  0.559256  0.515590     1.0
#            Date      Open      High       Low     Close  Adj Close    Volume  \
# 921  2020-12-01  0.915584  0.897508  0.908552  0.896546   0.902018  0.176317
# 922  2020-12-02  0.913069  0.925071  0.923561  0.926956   0.931850  0.254605
# 923  2020-12-03  0.943723  0.929654  0.942928  0.927783   0.932661  0.230082
# 924  2020-12-04  0.936059  0.922602  0.931429  0.922882   0.927853  0.531679
# 925  2020-12-07  0.929833  0.947931  0.939055  0.946501   0.951023  0.275715
#
#          MA10      MA30     EMA10     EMA30     MOM10     MOM30  signal
# 921  0.946999  0.996530  0.941309  0.990127  0.529403  0.644190     1.0
# 922  0.949448  0.999338  0.947666  0.992523  0.619262  0.655518     1.0
# 923  0.952692  1.000000  0.953026  0.994824  0.638314  0.549574     1.0
# 924  0.955342  0.998973  0.956471  0.996626  0.624062  0.466178     0.0
# 925  0.960540  0.998726  0.963821  1.000000  0.685118  0.504693     0.0

# %%
# Splitting entire data to create Training and Testing Data
# We will need to split the training and testing data into equivalent 
# time steps to train the Model

# Creating Training and Testing indices
train_data_size = int((0.7)*(input_df.shape[0]))
test_data_size = int(input_df.shape[0] - train_data_size)

# Allocating data instances to training and testing sets, excluding the date
train_data = input_df.iloc[0:train_data_size,1:]
test_data = input_df.iloc[train_data_size:input_df.shape[0],1:]


full_training_data = train_data # Used during model prediction
full_test_data = test_data  # Used during model prediction

# Creating numpy arrays from dataframes for future processing
train_data = np.array(train_data)
test_data = np.array(test_data)

print(train_data.shape)
print(test_data.shape)
# Out:
# (641, 13)
# (275, 13)

# %% [markdown]
# #### Time Series Data Creation

# %%
# Creating X_train and y_train
# As an example, this function looks back at five days of trading:
# X - Consists of all features excluding signal from last 5 days 
# y - Consists of signal from one day ahead

X_train = []
y_train = []

time_step = 5
label_col = (train_data.shape[1]-1)

for i in range(time_step, train_data.shape[0]):
    X_train.append(train_data[i-time_step:i,:label_col])
    y_train.append(train_data[i,label_col])
    
X_train, y_train = np.array(X_train), np.array(y_train)

print('\nShapes of X_train and Y_train:\n')
print(X_train.shape)
print(y_train.shape)

print('\nFirst Element in X_train and Y_train:\n')
print(X_train[0])
print(y_train[0])
# Out:
# Shapes of X_train and Y_train:
#
# (636, 5, 12)
# (636,)
#
# First Element in X_train and Y_train:
#
# [[0.01269232 0.01128351 0.00817044 0.00755833 0.00695175 0.30006288
#   0.00775412 0.00467232 0.00872021 0.00559628 0.57680761 0.53069376]
#  [0.00604681 0.00417254 0.00381287 0.00513728 0.00472498 0.36026166
#   0.00829904 0.00457398 0.00779729 0.00562866 0.57365725 0.51202936]
#  [0.00754354 0.00587682 0.00574957 0.00814881 0.00749475 0.20843027
#   0.0088878  0.00460458 0.0076199  0.00587419 0.57470734 0.51839466]
#  [0.00754354 0.00558299 0.00617321 0.00791261 0.00727752 0.10569089
#   0.00931371 0.00462643 0.00742946 0.00608699 0.57080698 0.5179631 ]
#  [0.00898042 0.00634696 0.00671791 0.00667258 0.00613704 0.11039296
#   0.00925734 0.00460021 0.00703575 0.00619744 0.55925583 0.51558963]]
# 1.0

# %%
# Creating X_test and y_test
# As an example, this function looks back at five days of trading:
# X - Consists of all features excluding signal from last 5 days 
# y - Consists of signal from one day ahead

X_test = []
y_test = []

# Gathering the last five days of training data as this 
# will be used to predict the first few labels in y_test
last_5_days = full_training_data.tail()
test_data_df = last_5_days.append([full_test_data], ignore_index=True)

for i in range(time_step, test_data_df.shape[0]):
    X_test.append(test_data_df.iloc[i-time_step:i,:label_col])
    y_test.append(test_data_df.iloc[i, label_col])

X_test, y_test = np.array(X_test), np.array(y_test)
print('\nShapes of X_test and Y_test:\n')
print(X_test.shape)
print(y_test.shape)

print('\nFirst Element in X_test and Y_test:\n')
print(X_test[0])
print(y_test[0])
# Out:
# Shapes of X_test and Y_test:
#
# (275, 5, 12)
# (275,)
#
# First Element in X_test and Y_test:
#
# [[0.49751537 0.4920075  0.4999697  0.49489226 0.49629384 0.0525501
#   0.51216045 0.51149725 0.50833919 0.51891265 0.58940882 0.59326792]
#  [0.50314312 0.4987659  0.5080191  0.50056103 0.50177783 0.09439732
#   0.51481615 0.51368262 0.51161846 0.52123556 0.62421239 0.62477076]
#  [0.50589716 0.49811945 0.50935058 0.50197816 0.50314878 0.07755281
#   0.51650727 0.5164493  0.51457336 0.52350988 0.60110996 0.65346861]
#  [0.5075735  0.50370242 0.51370815 0.50640686 0.50743307 0.10503956
#   0.51944482 0.51902367 0.51784061 0.52595399 0.63096304 0.64397455]
#  [0.5190085  0.5129878  0.52139443 0.51768529 0.51834381 0.14177104
#   0.52335946 0.52161334 0.52267747 0.52904648 0.65436533 0.64472983]]
# 1.0

# %% [markdown]
# ### Intial Modeling and Evaluation
# - Building, Compiling, and Training deep learning model
# - Evaluating model by comparing predicted signals against actual signals in testing data defined by X_test and y_test

# %%
# Model definition
def build_model():

    model = Sequential()  
   
    model.add(RNN(SimpleRNNCell(30 , activation = 'relu'), input_shape = (X_train.shape[1], X_train.shape[2])))
    model.add(Dropout(0.2))

    model.add(Dense(units = 10, activation = 'relu'))
    
    model.add(Dense(units = 1, activation = 'sigmoid'))
   
    print(model.summary())

    return model

# Model Compile
def compile_model(model):

    met = [keras.metrics.BinaryAccuracy(name='accuracy'),keras.metrics.Precision(name='precision'),
                keras.metrics.Recall(name='recall'), keras.metrics.AUC(name='auc')]
    
    model.compile(optimizer='adam', loss = BinaryCrossentropy(), metrics = met)

    return model

# Model Training
def train_model(model, X_train, Y_train):
    
    batch_size = 32
    epochs = 80

    #Capturing the unique counts of 0 and 1 signal classes
    (unique,counts) = np.unique(y_train, return_counts=True)
    frequencies = np.asarray((unique, counts)).T

    neg = frequencies[0][1]
    pos= frequencies[1][1]
    total = neg+pos

    #Calculating weights for teh two binary classes
    weight_for_0 = (1 / neg)*(total)/2.0 
    weight_for_1 = (1 / pos)*(total)/2.0
    
    #Defining parameters for the class weights
    cw = {0: weight_for_0, 1: weight_for_1}
       
    history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose = 1)

    return model, history

# Model Evaluation and Results Evaluation
def eval_model(m, test_X, test_y):

    y_pred = m.predict(test_X)
    y_pred = y_pred.flatten()
    
    print('CONFUSION MATRIX: \n')
    unique_label = np.unique([test_y, y_pred.round()])
    cmtx = pd.DataFrame(
    confusion_matrix(test_y, y_pred.round(), labels=unique_label), 
    index=['  true:{:}'.format(x) for x in unique_label], 
    columns=['pred:{:}'.format(x) for x in unique_label])
    print(cmtx)


    print('\nCLASSFICATION REPORT: \n')
    print(classification_report(test_y, y_pred.round()))

    # Visualising the results
    print('\nMODEL PREDICTIONS VS ACTUAL: \n')
    plt.figure(figsize=(14,5))
    plt.plot(test_y, color = 'red', label = 'Actual Buy/Sell Signal ')
    plt.plot(y_pred, color = 'blue', label = 'Predicted Buy/Sell Signal')
    plt.title('MSFT RNN Stock Buy/Sell Prediction - Without Twitter Sentiment')
    plt.xlabel('Time')
    plt.ylabel('MSFT Stock Signal')
    plt.legend(loc='best')
    plt.show()
   
    return None

# %%
# Class Imbalance
(unique,counts) = np.unique(y_train, return_counts=True)
frequencies = np.asarray((unique, counts)).T
print('Training Instances with Class 0:  ' + str(frequencies[0][1]))
print('Training Instances with Class 1:  ' + str(frequencies[1][1]))
total = int(frequencies[0][1]) + int(frequencies[1][1])
print('Total Training instances:  '+str(total))
# Out:
# Training Instances with Class 0:  190.0
# Training Instances with Class 1:  446.0
# Total Training instances:  636

# %%
# Executing model building, compiling and training 
# During model training, we print the 
model = build_model()
model = compile_model(model)
model, history = train_model(model, X_train, y_train)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rnn (RNN)                    (None, 30)                1290
# _________________________________________________________________
# dropout (Dropout)            (None, 30)                0
# _________________________________________________________________
# dense (Dense)                (None, 10)                310
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 1,611
# Trainable params: 1,611
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/80
# 20/20 [==============================] - 3s 6ms/step - loss: 0.6521 - accuracy: 0.6831 - precision: 0.7212 - recall: 0.9027 - auc: 0.5064
# Epoch 2/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.6140 - accuracy: 0.6966 - precision: 0.6966 - recall: 1.0000 - auc: 0.5438
# Epoch 3/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5859 - accuracy: 0.7132 - precision: 0.7132 - recall: 1.0000 - auc: 0.6213
# Epoch 4/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5883 - accuracy: 0.7111 - precision: 0.7111 - recall: 1.0000 - auc: 0.6196
# Epoch 5/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.6266 - accuracy: 0.6838 - precision: 0.6838 - recall: 1.0000 - auc: 0.5243
# Epoch 6/80
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6257 - accuracy: 0.6796 - precision: 0.6796 - recall: 1.0000 - auc: 0.5376
# Epoch 7/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5870 - accuracy: 0.7229 - precision: 0.7229 - recall: 1.0000 - auc: 0.5483
# Epoch 8/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.6061 - accuracy: 0.7008 - precision: 0.7008 - recall: 1.0000 - auc: 0.5450
# Epoch 9/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5895 - accuracy: 0.7089 - precision: 0.7089 - recall: 1.0000 - auc: 0.6234
# Epoch 10/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.6036 - accuracy: 0.6975 - precision: 0.6975 - recall: 1.0000 - auc: 0.5860
# Epoch 11/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.6098 - accuracy: 0.6837 - precision: 0.6837 - recall: 1.0000 - auc: 0.6169
# Epoch 12/80
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5962 - accuracy: 0.7068 - precision: 0.7068 - recall: 1.0000 - auc: 0.5860
# Epoch 13/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5977 - accuracy: 0.7022 - precision: 0.7022 - recall: 1.0000 - auc: 0.5966
# Epoch 14/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5765 - accuracy: 0.7004 - precision: 0.7004 - recall: 1.0000 - auc: 0.7281
# Epoch 15/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5689 - accuracy: 0.7212 - precision: 0.7212 - recall: 1.0000 - auc: 0.6614
# Epoch 16/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5956 - accuracy: 0.6902 - precision: 0.6902 - recall: 1.0000 - auc: 0.6540
# Epoch 17/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5923 - accuracy: 0.6988 - precision: 0.6988 - recall: 1.0000 - auc: 0.6272
# Epoch 18/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5800 - accuracy: 0.7019 - precision: 0.7003 - recall: 0.9992 - auc: 0.6818
# Epoch 19/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5800 - accuracy: 0.7052 - precision: 0.7029 - recall: 0.9992 - auc: 0.6678
# Epoch 20/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5702 - accuracy: 0.7229 - precision: 0.7177 - recall: 0.9947 - auc: 0.6790
# Epoch 21/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5471 - accuracy: 0.7592 - precision: 0.7521 - recall: 0.9944 - auc: 0.6755
# Epoch 22/80
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5773 - accuracy: 0.7259 - precision: 0.7211 - recall: 0.9789 - auc: 0.6849
# Epoch 23/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5742 - accuracy: 0.7196 - precision: 0.7193 - recall: 0.9746 - auc: 0.6920
# Epoch 24/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5717 - accuracy: 0.7287 - precision: 0.7271 - recall: 0.9776 - auc: 0.6701
# Epoch 25/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5690 - accuracy: 0.7323 - precision: 0.7397 - recall: 0.9551 - auc: 0.6574
# Epoch 26/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5590 - accuracy: 0.7236 - precision: 0.7167 - recall: 0.9775 - auc: 0.7497
# Epoch 27/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5894 - accuracy: 0.7111 - precision: 0.7112 - recall: 0.9736 - auc: 0.7001
# Epoch 28/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5365 - accuracy: 0.7439 - precision: 0.7376 - recall: 0.9794 - auc: 0.7389
# Epoch 29/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5162 - accuracy: 0.7626 - precision: 0.7641 - recall: 0.9658 - auc: 0.7446
# Epoch 30/80
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5103 - accuracy: 0.7626 - precision: 0.7655 - recall: 0.9602 - auc: 0.7588
# Epoch 31/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5079 - accuracy: 0.7620 - precision: 0.7767 - recall: 0.9247 - auc: 0.7827
# Epoch 32/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5528 - accuracy: 0.7379 - precision: 0.7471 - recall: 0.9278 - auc: 0.7199
# Epoch 33/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5107 - accuracy: 0.7507 - precision: 0.7502 - recall: 0.9577 - auc: 0.7762
# Epoch 34/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.4751 - accuracy: 0.7822 - precision: 0.7740 - recall: 0.9684 - auc: 0.8244
# Epoch 35/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.4420 - accuracy: 0.7941 - precision: 0.7892 - recall: 0.9677 - auc: 0.8361
# Epoch 36/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5067 - accuracy: 0.7761 - precision: 0.7759 - recall: 0.9346 - auc: 0.7877
# Epoch 37/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.4634 - accuracy: 0.7939 - precision: 0.7911 - recall: 0.9400 - auc: 0.8345
# Epoch 38/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5054 - accuracy: 0.7818 - precision: 0.8143 - recall: 0.8718 - auc: 0.8072
# Epoch 39/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.4630 - accuracy: 0.7797 - precision: 0.7777 - recall: 0.9633 - auc: 0.8204
# Epoch 40/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.4087 - accuracy: 0.8216 - precision: 0.8237 - recall: 0.9434 - auc: 0.8770
# Epoch 41/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.4045 - accuracy: 0.8016 - precision: 0.8200 - recall: 0.9209 - auc: 0.8715
# Epoch 42/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3881 - accuracy: 0.8271 - precision: 0.8428 - recall: 0.9213 - auc: 0.8816
# Epoch 43/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3717 - accuracy: 0.8421 - precision: 0.8605 - recall: 0.9207 - auc: 0.8981
# Epoch 44/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3598 - accuracy: 0.8458 - precision: 0.8631 - recall: 0.9204 - auc: 0.8986
# Epoch 45/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.4158 - accuracy: 0.8259 - precision: 0.8320 - recall: 0.9391 - auc: 0.8578
# Epoch 46/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3954 - accuracy: 0.8325 - precision: 0.8411 - recall: 0.9386 - auc: 0.8704
# Epoch 47/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3623 - accuracy: 0.8447 - precision: 0.8549 - recall: 0.9369 - auc: 0.8959
# Epoch 48/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3646 - accuracy: 0.8394 - precision: 0.8517 - recall: 0.9412 - auc: 0.8801
# Epoch 49/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3456 - accuracy: 0.8584 - precision: 0.8619 - recall: 0.9546 - auc: 0.9045
# Epoch 50/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3824 - accuracy: 0.8494 - precision: 0.8539 - recall: 0.9456 - auc: 0.8817
# Epoch 51/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3849 - accuracy: 0.8344 - precision: 0.8540 - recall: 0.9246 - auc: 0.8765
# Epoch 52/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.4022 - accuracy: 0.8125 - precision: 0.8152 - recall: 0.9331 - auc: 0.8864
# Epoch 53/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.4022 - accuracy: 0.8202 - precision: 0.8306 - recall: 0.9326 - auc: 0.8775
# Epoch 54/80
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3835 - accuracy: 0.8342 - precision: 0.8666 - recall: 0.8975 - auc: 0.8863
# Epoch 55/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3788 - accuracy: 0.8510 - precision: 0.8754 - recall: 0.9194 - auc: 0.8838
# Epoch 56/80
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3503 - accuracy: 0.8496 - precision: 0.8504 - recall: 0.9540 - auc: 0.9039
# Epoch 57/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3656 - accuracy: 0.8456 - precision: 0.8622 - recall: 0.9294 - auc: 0.8891
# Epoch 58/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3866 - accuracy: 0.8277 - precision: 0.8298 - recall: 0.9506 - auc: 0.8882
# Epoch 59/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3725 - accuracy: 0.8594 - precision: 0.8906 - recall: 0.9134 - auc: 0.8967
# Epoch 60/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3539 - accuracy: 0.8444 - precision: 0.8623 - recall: 0.9323 - auc: 0.8925
# Epoch 61/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3685 - accuracy: 0.8421 - precision: 0.8556 - recall: 0.9269 - auc: 0.8898
# Epoch 62/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3485 - accuracy: 0.8604 - precision: 0.8683 - recall: 0.9474 - auc: 0.8899
# Epoch 63/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3630 - accuracy: 0.8429 - precision: 0.8639 - recall: 0.9162 - auc: 0.8958
# Epoch 64/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3796 - accuracy: 0.8367 - precision: 0.8648 - recall: 0.9068 - auc: 0.8823
# Epoch 65/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3325 - accuracy: 0.8638 - precision: 0.8715 - recall: 0.9455 - auc: 0.9082
# Epoch 66/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3308 - accuracy: 0.8780 - precision: 0.8807 - recall: 0.9560 - auc: 0.9038
# Epoch 67/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3517 - accuracy: 0.8414 - precision: 0.8677 - recall: 0.9174 - auc: 0.8912
# Epoch 68/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3344 - accuracy: 0.8757 - precision: 0.8723 - recall: 0.9588 - auc: 0.9144
# Epoch 69/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3520 - accuracy: 0.8599 - precision: 0.8798 - recall: 0.9271 - auc: 0.8930
# Epoch 70/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3208 - accuracy: 0.8712 - precision: 0.8975 - recall: 0.9257 - auc: 0.9081
# Epoch 71/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3384 - accuracy: 0.8635 - precision: 0.8510 - recall: 0.9646 - auc: 0.9145
# Epoch 72/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3217 - accuracy: 0.8726 - precision: 0.8932 - recall: 0.9285 - auc: 0.9234
# Epoch 73/80
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3464 - accuracy: 0.8559 - precision: 0.8640 - recall: 0.9439 - auc: 0.8976
# Epoch 74/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3456 - accuracy: 0.8378 - precision: 0.8460 - recall: 0.9375 - auc: 0.9045
# Epoch 75/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3365 - accuracy: 0.8700 - precision: 0.8951 - recall: 0.9338 - auc: 0.8971
# Epoch 76/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3214 - accuracy: 0.8631 - precision: 0.8953 - recall: 0.9191 - auc: 0.9143
# Epoch 77/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3875 - accuracy: 0.8057 - precision: 0.8361 - recall: 0.8892 - auc: 0.8806
# Epoch 78/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3618 - accuracy: 0.8293 - precision: 0.8358 - recall: 0.9300 - auc: 0.8990
# Epoch 79/80
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3699 - accuracy: 0.8522 - precision: 0.8630 - recall: 0.9373 - auc: 0.8884
# Epoch 80/80
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3607 - accuracy: 0.8663 - precision: 0.8766 - recall: 0.9491 - auc: 0.8541

# %%
# Plotting Training loss vs Epochs 
def plot_curves(history): 
    
    print('\nMODEL TRAINING RESULTS\n')
    plt.figure(figsize=(10,10))
    plt.plot(history.history['loss'], color = 'blue')
    plt.plot(history.history['accuracy'], color = 'red')
    plt.title('Model Training Loss & Accuracy vs Epochs')
    plt.xlabel('Training Epochs')
    plt.legend(['Train Loss', 'Train Accuracy'], loc='best')
    plt.show()
        
plot_curves(history)
# Out:
# MODEL TRAINING RESULTS

# %%
# Testing Initial Model 
# Printing Confusion Matrix, Classification Report, and Visualizing Predicted Signal
tf.keras.utils.plot_model(model, to_file='MSFT-RNN-without-Sentiment-Normal.png', show_shapes=True)
eval_model(model, X_test, y_test)
# Out:
# CONFUSION MATRIX:
#
#             pred:0.0  pred:1.0
#   true:0.0        47        26
#   true:1.0         5       197
#
# CLASSFICATION REPORT:
#
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.64      0.75        73
#          1.0       0.88      0.98      0.93       202
#
#     accuracy                           0.89       275
#    macro avg       0.89      0.81      0.84       275
# weighted avg       0.89      0.89      0.88       275
#
#
# MODEL PREDICTIONS VS ACTUAL:

# %% [markdown]
# ### Hyperparameter Tuning
# - Creating Hyper parameter model and using the RandomSearch tuner class for performing tuning.
# - Tuner obtains the best values for hyperparameters such as input llayer units, input lyaer dropout, hidden layer cells, and learning rate
# - Using the best values, we create another model to find the optimal number
# of epochs which minimizes training loss
# - Lastly, create a final model which uses the optimal values for hyperparameters and epochs to build the best model and performing evaluation

# %%
def model_builder(hp):

    #Defining Model 
    hyper_model = Sequential()

    hyper_model.add(RNN(SimpleRNNCell(hp.Int('input_layer', 10, 90, step=10), activation = 'relu'), 
                                      input_shape = (X_train.shape[1], X_train.shape[2])))
    hyper_model.add(Dropout(hp.Choice('Drop1', values = [0.1,0.2,0.3])))
        
    hyper_model.add(Dense(units = hp.Choice('hidden_1', values = [10,20,30,60,80,100]), activation = 'relu'))
        
    hyper_model.add(Dense(units = 1, activation = 'sigmoid'))
        
    hyper_model.compile(optimizer = Adam(learning_rate=hp.Choice('learning_rate', values = [1e-2, 1e-3, 1e-4])),
                        loss = BinaryCrossentropy(), metrics=['accuracy'])
        
    return hyper_model

# %%
# Defining Random Search Tuner and performing hyperparameter tuning
obj = kt.Objective("loss", direction="min")
tuner = kt.tuners.randomsearch.RandomSearch(model_builder, objective=obj, max_trials=25, seed=42, overwrite = True)

tuner.search(X_train, y_train, epochs=80)

# Get the optimal hyperparameter values for model layers
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
The hyperparameter search is complete. 

The optimal number of units in the input layer is {best_hps.get('input_layer')}. 
The optimal amount of dropout in the input layer is {best_hps.get('Drop1')}. 
The optimal number of units in the first hidden layer is {best_hps.get('hidden_1')}. 
The optimal learning rate is {best_hps.get('learning_rate')}.
""")
# Out:
# Trial 25 Complete [00h 00m 08s]
# loss: 0.5664907693862915
#
# Best loss So Far: 0.2692052125930786
# Total elapsed time: 00h 03m 31s
# INFO:tensorflow:Oracle triggered exit
#
# The hyperparameter search is complete.
#
# The optimal number of units in the input layer is 70.
# The optimal amount of dropout in the input layer is 0.1.
# The optimal number of units in the first hidden layer is 20.
# The optimal learning rate is 0.001.

# %% [markdown]
# #### Evaluating Tuned Model
# - In Step One, we create the model using the best hyperparameter values identified during tuning. Then we find the epoch in which we obtain our objective.
#
# - In Step Two, we recreate the model using the optimal hyperparameter values and the ideal number of training epochs. Then we train and evaluate this model to compare results against the first non-tuned model with random parameters

# %%
#Step One
model_Two = tuner.hypermodel.build(best_hps)
history = model_Two.fit(X_train, y_train, epochs=80)

acc_per_epoch = history.history['accuracy']
best_epoch = acc_per_epoch.index(max(acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Epoch 1/80
# 20/20 [==============================] - 1s 4ms/step - loss: 0.6546 - accuracy: 0.5870
# Epoch 2/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6035 - accuracy: 0.6966
# Epoch 3/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5939 - accuracy: 0.7132
# Epoch 4/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5880 - accuracy: 0.7111
# Epoch 5/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6071 - accuracy: 0.6884
# Epoch 6/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6013 - accuracy: 0.6942
# Epoch 7/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5518 - accuracy: 0.7413
# Epoch 8/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5640 - accuracy: 0.7221
# Epoch 9/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5405 - accuracy: 0.7340
# Epoch 10/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5766 - accuracy: 0.7014
# Epoch 11/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5413 - accuracy: 0.7244
# Epoch 12/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5454 - accuracy: 0.7357
# Epoch 13/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5184 - accuracy: 0.7377
# Epoch 14/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5095 - accuracy: 0.7565
# Epoch 15/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4665 - accuracy: 0.7706
# Epoch 16/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4602 - accuracy: 0.7841
# Epoch 17/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4469 - accuracy: 0.7768
# Epoch 18/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4108 - accuracy: 0.8112
# Epoch 19/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4424 - accuracy: 0.7985
# Epoch 20/80
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3905 - accuracy: 0.8239
# Epoch 21/80
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3704 - accuracy: 0.8330
# Epoch 22/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4029 - accuracy: 0.8109
# Epoch 23/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3872 - accuracy: 0.8129
# Epoch 24/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3322 - accuracy: 0.8588
# Epoch 25/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3824 - accuracy: 0.8223
# Epoch 26/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4294 - accuracy: 0.7929
# Epoch 27/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4249 - accuracy: 0.8144
# Epoch 28/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3576 - accuracy: 0.8350
# Epoch 29/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3348 - accuracy: 0.8608
# Epoch 30/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3918 - accuracy: 0.8181
# Epoch 31/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3445 - accuracy: 0.8535
# Epoch 32/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3573 - accuracy: 0.8528
# Epoch 33/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3777 - accuracy: 0.8321
# Epoch 34/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3646 - accuracy: 0.8462
# Epoch 35/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3517 - accuracy: 0.8498
# Epoch 36/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4852 - accuracy: 0.7842
# Epoch 37/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3798 - accuracy: 0.8256
# Epoch 38/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3346 - accuracy: 0.8612
# Epoch 39/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4054 - accuracy: 0.8164
# Epoch 40/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3649 - accuracy: 0.8370
# Epoch 41/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3302 - accuracy: 0.8483
# Epoch 42/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3120 - accuracy: 0.8760
# Epoch 43/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3122 - accuracy: 0.8624
# Epoch 44/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3146 - accuracy: 0.8782
# Epoch 45/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3762 - accuracy: 0.8445
# Epoch 46/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3734 - accuracy: 0.8363
# Epoch 47/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3183 - accuracy: 0.8497
# Epoch 48/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3061 - accuracy: 0.8921
# Epoch 49/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3201 - accuracy: 0.8675
# Epoch 50/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3493 - accuracy: 0.8401
# Epoch 51/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3316 - accuracy: 0.8490
# Epoch 52/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3256 - accuracy: 0.8577
# Epoch 53/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3399 - accuracy: 0.8490
# Epoch 54/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4035 - accuracy: 0.8102
# Epoch 55/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3489 - accuracy: 0.8436
# Epoch 56/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3149 - accuracy: 0.8591
# Epoch 57/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3116 - accuracy: 0.8606
# Epoch 58/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3585 - accuracy: 0.8374
# Epoch 59/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3136 - accuracy: 0.8702
# Epoch 60/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3294 - accuracy: 0.8712
# Epoch 61/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3349 - accuracy: 0.8541
# Epoch 62/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2943 - accuracy: 0.8711
# Epoch 63/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3251 - accuracy: 0.8511
# Epoch 64/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3324 - accuracy: 0.8353
# Epoch 65/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3267 - accuracy: 0.8459
# Epoch 66/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3187 - accuracy: 0.8487
# Epoch 67/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3301 - accuracy: 0.8751
# Epoch 68/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2908 - accuracy: 0.8853
# Epoch 69/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3485 - accuracy: 0.8627
# Epoch 70/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3235 - accuracy: 0.8624
# Epoch 71/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3115 - accuracy: 0.8489
# Epoch 72/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3365 - accuracy: 0.8509
# Epoch 73/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3125 - accuracy: 0.8731
# Epoch 74/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3460 - accuracy: 0.8484
# Epoch 75/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2993 - accuracy: 0.8908
# Epoch 76/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3289 - accuracy: 0.8568
# Epoch 77/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4068 - accuracy: 0.8143
# Epoch 78/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3470 - accuracy: 0.8492
# Epoch 79/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3198 - accuracy: 0.8543
# Epoch 80/80
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3172 - accuracy: 0.8657
# Best epoch: 75

# %%
#Step Two
model_three = tuner.hypermodel.build(best_hps)

# Retrain the final model using the best number of epochs
tuned_history = model_three.fit(X_train, y_train, epochs=best_epoch)
# Out:
# Epoch 1/75
# 20/20 [==============================] - 1s 4ms/step - loss: 0.6376 - accuracy: 0.6895
# Epoch 2/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6078 - accuracy: 0.6966
# Epoch 3/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5914 - accuracy: 0.7132
# Epoch 4/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5856 - accuracy: 0.7111
# Epoch 5/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6022 - accuracy: 0.6838
# Epoch 6/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6036 - accuracy: 0.6796
# Epoch 7/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5594 - accuracy: 0.7229
# Epoch 8/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5702 - accuracy: 0.7094
# Epoch 9/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5489 - accuracy: 0.7401
# Epoch 10/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5703 - accuracy: 0.7205
# Epoch 11/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5448 - accuracy: 0.7216
# Epoch 12/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5528 - accuracy: 0.7284
# Epoch 13/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5395 - accuracy: 0.7269
# Epoch 14/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5075 - accuracy: 0.7459
# Epoch 15/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4977 - accuracy: 0.7644
# Epoch 16/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5055 - accuracy: 0.7455
# Epoch 17/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5127 - accuracy: 0.7400
# Epoch 18/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4796 - accuracy: 0.7812
# Epoch 19/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4972 - accuracy: 0.7532
# Epoch 20/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4512 - accuracy: 0.7755
# Epoch 21/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4246 - accuracy: 0.7952
# Epoch 22/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4430 - accuracy: 0.8020
# Epoch 23/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4373 - accuracy: 0.7905
# Epoch 24/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4120 - accuracy: 0.8204
# Epoch 25/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4531 - accuracy: 0.7729
# Epoch 26/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4878 - accuracy: 0.7559
# Epoch 27/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4382 - accuracy: 0.7685
# Epoch 28/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3765 - accuracy: 0.8213
# Epoch 29/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3519 - accuracy: 0.8610
# Epoch 30/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4358 - accuracy: 0.7879
# Epoch 31/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3922 - accuracy: 0.8196
# Epoch 32/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4276 - accuracy: 0.8031
# Epoch 33/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4338 - accuracy: 0.8066
# Epoch 34/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3910 - accuracy: 0.8268
# Epoch 35/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3617 - accuracy: 0.8334
# Epoch 36/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4278 - accuracy: 0.7987
# Epoch 37/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3908 - accuracy: 0.8216
# Epoch 38/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3627 - accuracy: 0.8344
# Epoch 39/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4283 - accuracy: 0.8104
# Epoch 40/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3573 - accuracy: 0.8446
# Epoch 41/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3421 - accuracy: 0.8368
# Epoch 42/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3086 - accuracy: 0.8727
# Epoch 43/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3218 - accuracy: 0.8566
# Epoch 44/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2990 - accuracy: 0.8868
# Epoch 45/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4046 - accuracy: 0.8281
# Epoch 46/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4107 - accuracy: 0.8101
# Epoch 47/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3274 - accuracy: 0.8397
# Epoch 48/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3003 - accuracy: 0.8630
# Epoch 49/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3303 - accuracy: 0.8518
# Epoch 50/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3748 - accuracy: 0.8248
# Epoch 51/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3307 - accuracy: 0.8565
# Epoch 52/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3356 - accuracy: 0.8614
# Epoch 53/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3360 - accuracy: 0.8515
# Epoch 54/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4231 - accuracy: 0.8047
# Epoch 55/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3854 - accuracy: 0.8223
# Epoch 56/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3278 - accuracy: 0.8400
# Epoch 57/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3133 - accuracy: 0.8625
# Epoch 58/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3619 - accuracy: 0.8396
# Epoch 59/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3204 - accuracy: 0.8623
# Epoch 60/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3524 - accuracy: 0.8578
# Epoch 61/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3238 - accuracy: 0.8554
# Epoch 62/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3031 - accuracy: 0.8796
# Epoch 63/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3199 - accuracy: 0.8435
# Epoch 64/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3246 - accuracy: 0.8464
# Epoch 65/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3211 - accuracy: 0.8582
# Epoch 66/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3180 - accuracy: 0.8543
# Epoch 67/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3092 - accuracy: 0.8643
# Epoch 68/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2908 - accuracy: 0.8812
# Epoch 69/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3738 - accuracy: 0.8300
# Epoch 70/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3451 - accuracy: 0.8618
# Epoch 71/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3337 - accuracy: 0.8448
# Epoch 72/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3031 - accuracy: 0.8705
# Epoch 73/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3061 - accuracy: 0.8634
# Epoch 74/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3447 - accuracy: 0.8477
# Epoch 75/75
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3053 - accuracy: 0.8932

# %%
plot_curves(tuned_history)
# Out:
# MODEL TRAINING RESULTS

# %%
# Tuned Model Evaluation
# Printing Confusion Matrix, Classification Report, and Visualizing the Predicted Signal
eval_result = model_three.evaluate(X_test, y_test)
print("[test loss, test accuracy]:", eval_result)
tf.keras.utils.plot_model(model_three, to_file='MSFT-RNN-without-Sentiment-Tuned.png', show_shapes=True)
eval_model(model_three, X_test, y_test)
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 0.5117 - accuracy: 0.8364
# [test loss, test accuracy]: [0.5116840600967407, 0.8363636136054993]
# CONFUSION MATRIX:
#
#             pred:0.0  pred:1.0
#   true:0.0        28        45
#   true:1.0         0       202
#
# CLASSFICATION REPORT:
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.38      0.55        73
#          1.0       0.82      1.00      0.90       202
#
#     accuracy                           0.84       275
#    macro avg       0.91      0.69      0.73       275
# weighted avg       0.87      0.84      0.81       275
#
#
# MODEL PREDICTIONS VS ACTUAL:
